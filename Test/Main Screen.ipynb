# %%
import tkinter as tk
from tkinter import ttk

window = tk.Tk()
window.geometry("600x600")

Header = tk.Label(text="MEDSMART X-RAY SOLUTIONS", font=("Arial", 22))
Header.place(x=300, y=55, anchor="center")

Type = tk.Label(text="Choose a Scan Type: ", font=("Arial", 14))
Type.place(x=200, y=125, anchor="center")

c = tk.StringVar()
Combo = ttk.Combobox(window, width=25, textvariable = c, state="readonly")
Combo['values'] = ("Brain Tumor Detection",
                   "Knee Osteoarthritis Detection",
                   "Chest Infection Detection",
                   "Lung Cancer Detection", 
                   "Breast Cancer Detection")
Combo.current(0)
Combo.place(x=425, y=125, anchor='center')

Upload = tk.Button(text="UPLOAD IMAGE")
Upload.place(x=300 ,y=180 ,anchor = 'center')

"""
DISPLAY IMAGE CODE HERE
"""

Results = tk.Button(text="DISPLAY RESULTS")
Results.place(x=300, y=475, anchor="center")

Report = tk.Button(text="PRINT REPORT")
Report.place(x=300, y=525, anchor="center")

window.mainloop()

# %%
window2 = tk.Tk()
window2.geometry("500x500")

header = tk.Label(text="MEDSMART X-RAY SOLUTIONS", font=("Arial", 22))
header.place(x=250, y=55, anchor="center")

Stype = tk.Label(text="Scan Type: ", font=("Arial", 14))
Stype.place(x=200, y=125, anchor="center")

"""
GET VALUE FROM PREVIOUS SCREEN FOR SCAN TYPE
"""

"""
GET PROBABILITY VALUES FROM PREVIOUS SCREEN FOR TABLE
"""

window2.mainloop()

# %%
window3 = tk.Tk()
window3.geometry("500x650")

header = tk.Label(text="MEDSMART X-RAY SOLUTIONS", font=("Arial", 22))
header.place(x=250, y=55, anchor="center")

FileNum = tk.Label(text="File Number:", font=("Arial",12))
FileNum.place(x=125, y=100, anchor="center")
text1 = tk.Entry()
text1.place(x=300, y=100, anchor="center")

Name = tk.Label(text="Patient Name:", font=("Arial",12))
Name.place(x=125, y=125, anchor="center")
text2 = tk.Entry()
text2.place(x=300, y=125, anchor="center")

DOB = tk.Label(text="Date of Birth:", font=("Arial",12))
DOB.place(x=125, y=150, anchor="center")
text3 = tk.Entry()
text3.place(x=300, y=150, anchor="center")

DOS = tk.Label(text="Date of Study:", font=("Arial",12))
DOS.place(x=125, y=175, anchor="center")
text4 = tk.Entry()
text4.place(x=300, y=175, anchor="center")

DOR = tk.Label(text="Date of Report:", font=("Arial",12))
DOR.place(x=125, y=200, anchor="center")
text5 = tk.Entry()
text5.place(x=300, y=200, anchor="center")

ST = tk.Label(text="Scan Type:", font=("Arial",12))
ST.place(x=125, y=225, anchor="center")
text6 = tk.Entry()
text6.place(x=300, y=225, anchor="center")

Title = tk.Label(text="Title of Study:", font=("Arial",12))
Title.place(x=125, y=250, anchor="center")
text7 = tk.Entry()
text7.place(x=300, y=250, anchor="center")

Findings = tk.Label(text="Findings:", font=("Arial",12))
Findings.place(x=125, y=280, anchor="center")
t1 = tk.Text(window3,  height=5, width=25)# added one text box
t1.place(x=340, y=315, anchor="center")

Impressions = tk.Label(text="Impressions:", font=("Arial",12))
Impressions.place(x=125, y=375, anchor="center")
t2 = tk.Text(window3,  height=5, width=25)# added one text box
t2.place(x=340, y=405, anchor="center")

Human = tk.Label(text="Human Study Results:", font=("Arial",12))
Human.place(x=125, y=470, anchor="center")
t3 = tk.Text(window3,  height=5, width=25)# added one text box
t3.place(x=340, y=500, anchor="center")

Adds = tk.Label(text="Additionals:", font=("Arial",12))
Adds.place(x=125, y=560, anchor="center")
t4 = tk.Text(window3,  height=2, width=25)# added one text box
t4.place(x=340, y=570, anchor="center")

def getInputs():
    global x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11
    x1 = str(text1.get())
    x2 = str(text2.get())
    x3 = str(text3.get())
    x4 = str(text4.get())
    x5 = str(text5.get())
    x6 = str(text6.get())
    x7 = str(text7.get())
    x8 = str(t1.get("1.0",'end-1c'))
    x9 = str(t2.get("1.0",'end-1c'))
    x10 = str(t3.get("1.0",'end-1c'))
    x11 = str(t4.get("1.0",'end-1c'))
    print(x1,x2,x3,x10,x11) 

Generate = tk.Button(text="Generate REPORT", command=getInputs)
Generate.place(x=250, y=610, anchor="center")


window3.mainloop()
# Out:
#    vkbjnkl m,. bknlk
